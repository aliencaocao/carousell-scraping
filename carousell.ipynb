# %%
import sys, os
import time
import re
import urllib
from pprint import pprint
import pandas as pd
import bs4
from bs4 import BeautifulSoup
import selenium
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.common.exceptions import TimeoutException
print(f'Carousell Scraping V1.0 by Billy Cao\nRunning on Python {sys.version}, Selenium {selenium.__version__}, BeautifulSoup {bs4.__version__}')

def request_page(url):
    """ Returns BeautifulSoup4 Objects (soup)"""
    driver.get(url)
    page = 1
    timeout = 5
    while page < page_limit:
        try:
            next_page_btn = WebDriverWait(driver, timeout).until(EC.presence_of_element_located((By.XPATH, '//main[1]/div/button[.="Load more"]')))  # wait max timeout sec for loading
            driver.execute_script("arguments[0].click();", next_page_btn)  # click the load more button through ads
            page += 1
        except TimeoutException as e:
            break
    time.sleep(timeout)
    print(f'All results loaded. Total: {page} pages.')
    return BeautifulSoup(driver.page_source, "html.parser")

def parse_info(item_div, mode=1):
    a = item_div.div.find_all('a', recursive=False)
    seller_divs = a[0].find_all('div', recursive=False)[1]
    item_p = a[1].find_all('p', recursive=False)
    if mode == 1:
        return {'seller_name': seller_divs.p.get_text(),
                'seller_url': home+a[0]['href'],
                'item_name': a[1].find_all('div', recursive=False)[1].p.get_text(),
                'item_url': home+a[1]['href'],
                'time_posted': seller_divs.div.p.get_text(),  # TODO: process into absolute datetime
                'condition': item_p[1].get_text(),
                'price': re.findall(r"\d+", item_p[0].get_text().replace(',', ''))[0]}  # 0 is discounted price, 1 is original price, if applicable
    else:
        return {'seller_name': seller_divs.p.get_text(),
                'seller_url': home+a[0]['href'],
                'item_name': item_p[0].get_text(),
                'item_url': home+a[1]['href'],
                'time_posted': seller_divs.div.p.get_text(),  # TODO: process into absolute datetime
                'condition': item_p[3].get_text(),
                'price': re.findall(r"\d+", item_p[1].get_text().replace(',', ''))[0]}  # 0 is discounted price, 1 is original price, if applicable

home = 'https://sg.carousell.com'
item = input('Enter item to scrape: ')
page_limit = int(input('Up to how many pages to scrap? Each page is 23-25 listings: '))
extension = f'/search/{urllib.parse.quote(item)}'
opts = Options()
opts.add_experimental_option('prefs', {'intl.accept_languages': 'en,en_US'})
driver = webdriver.Chrome(options=opts)
driver.minimize_window()
print(f'Chrome Web Driver loaded. Version: {driver.capabilities["browserVersion"]}\n')  # use "version" on Linux
parse_mode = 1  # Carousell have 2 formats of their item divs. See below comment for more info.
tries = 1

while tries < 5:  # retrying loop as the div class position is random
    try:
        print(f'Retrieving search results on {item}...')
        search_results_soup = request_page(home+extension)
        # TODO: Find concrete way to locate correct class name, current work around works 99% of times.
        item_divs_class = ' '.join(search_results_soup.find('main').find('div').find('div').find('div')['class'])  # changes randomly but 99% of the time its the first div
        print(f'Detected item_divs class: {item_divs_class}')
        item_divs = search_results_soup.find('main').find('div').find('div').find_all('div', class_=item_divs_class, recursive=False)  # filter out ads divs
        print(f'Found {len(item_divs)} listings. Parsing...')
        items_list = [parse_info(item_div, parse_mode) for item_div in item_divs]
        break
    except AttributeError as e:  # no item_divs at all
        raise RuntimeError('The search has returned no result.')
    except IndexError as e:
        print(f'Parsing attempt {tries} failed due to class name error using parse mode {parse_mode}. Retrying with parse mode 2...\n')
        tries += 1
        parse_mode = 2
        continue
else:
    raise RuntimeError('Parsing failed as it still faces IndexError after 5 tries.')

driver.quit()
print(f'Parse success using mode {parse_mode}! Sample item parsed:')
pprint(items_list[0])
df = pd.DataFrame(items_list)
print(df.describe())
print(df)
df.to_csv(f'{item}.csv', index=False)
print(f'Results saved to {item}.csv')

'''
Two parse modes only differs in item divs 2nd a
Structure of Carousell HTML FORMAT 1 (parse_mode 1):
body > find main > 1st div > 1st div > divs of items
    in divs of items > parents of each item
        parent > 1st div > 1st a is seller, 2nd a is item page
            in 1st a: 2nd div > p is seller name, > div > p is time posted
            in 2nd a: 2nd div > p is item name but with ... if too long, directly under 2nd a first p is price, 2nd p is condition
        parent > 2nd div > button > span is number of likes
total 24 or 25 results loaded once.

Structure of Carousell HTML FORMAT 2 (parse_mode 2):
body > find main > 1st div > 1st div > divs of items
    in divs of items > parents of each item
        parent > 1st div > 1st a is seller, 2nd a is item page
            in 1st a: 2nd div > p is seller name, > div > p is time posted
            in 2nd a: 1st p is FULl NAME, 2nd p is price, 3rd p is description, 4th p is condition
        parent > 2nd div > button > span is number of likes
total 24 or 25 results loaded once.

body > find main > div > button to view more
view more button loads on top of existing, so can prob spam view more then gather all items at once
MAY NOT BE FIRST DIV! Temp workaround is to get class name of the correct item divs
'''
# Out:
# Carousell Scraping V1.0 by Billy Cao
# Running on Python 3.8.10 (tags/v3.8.10:3d8993a, May  3 2021, 11:48:03) [MSC v.1928 64 bit (AMD64)], Selenium 3.141.0, BeautifulSoup 4.9.3
# Chrome Web Driver loaded. Version: 92.0.4515.131
#
# Retrieving search results on rtx 3080ti...
# All results loaded. Total: 3 pages.
# Detected item_divs class: D_aK D_hA D_hI
# Found 56 listings. Parsing...
# Parsing attempt 1 failed due to class name error using parse mode 1. Retrying with parse mode 2...
#
# Retrieving search results on rtx 3080ti...
# All results loaded. Total: 3 pages.
# Detected item_divs class: D_aK D_hA D_hI
# Found 56 listings. Parsing...
# Parse success using mode 2! Sample item parsed:
# {'condition': 'Brand new',
#  'item_name': 'RTX 3060 TI LHR (3060TI), RTX 3080 LHR, GTX 1660 SUPER (1660S), '
#               'TUF RX6800XT, ZOTAC RTX 3080 TI (3080TI)',
#  'item_url': 'https://sg.carousell.com/p/rtx-3060-ti-lhr-3060ti-rtx-3080-lhr-gtx-1660-super-1660s-tuf-rx6800xt-zotac-rtx-3080-ti-3080ti-1098207022/?t-id=SOoe-C9UJC_1628349788210&t-referrer_browse_type=search_results&t-referrer_request_id=Io2p6I6bQVIcJlT7&t-referrer_search_query=rtx%203080ti&t-referrer_sort_by=popular',
#  'price': '1100',
#  'seller_name': 'mxware_west',
#  'seller_url': 'https://sg.carousell.com/mxware_west/?t-id=SOoe-C9UJC_1628349788210&t-source=search_results&t-source_query=rtx%203080ti',
#  'time_posted': '12 hours ago'}
#        seller_name                                         seller_url  \
# count           56                                                 56
# unique          35                                                 35
# top     bizdealers  https://sg.carousell.com/bizdealers/?t-id=SOoe...
# 37           qualitybuilds  https://sg.carousell.com/qualitybuilds/?t-id=S...
# 38              modztechsg  https://sg.carousell.com/modztechsg/?t-id=SOoe...
# 39            keanetobuild  https://sg.carousell.com/keanetobuild/?t-id=SO...
# 40     luxury_watch_straps  https://sg.carousell.com/luxury_watch_straps/?...
# 41          borneorockstar  https://sg.carousell.com/borneorockstar/?t-id=...
# 42             piratephoto  https://sg.carousell.com/piratephoto/?t-id=SOo...
# 43                 dont.bb  https://sg.carousell.com/dont.bb/?t-id=SOoe-C9...
# 44                amplific  https://sg.carousell.com/amplific/?t-id=SOoe-C...
# 45                possivei  https://sg.carousell.com/possivei/?t-id=SOoe-C...
# 46           teencomputing  https://sg.carousell.com/teencomputing/?t-id=S...
# 47                 zhapkua  https://sg.carousell.com/zhapkua/?t-id=SOoe-C9...
# 48          borneorockstar  https://sg.carousell.com/borneorockstar/?t-id=...
# 49               disque_pc  https://sg.carousell.com/disque_pc/?t-id=SOoe-...
# 50             techdealssg  https://sg.carousell.com/techdealssg/?t-id=SOo...
# 51               sakura-02  https://sg.carousell.com/sakura-02/?t-id=SOoe-...
# 52                aviciiii  https://sg.carousell.com/aviciiii/?t-id=SOoe-C...
# 53  sellanythingeverything  https://sg.carousell.com/sellanythingeverythin...
# 54              omnidirect  https://sg.carousell.com/omnidirect/?t-id=SOoe...
# 55                   cmhsy  https://sg.carousell.com/cmhsy/?t-id=SOoe-C9UJ...
#
#                                             item_name  \
# 0   RTX 3060 TI LHR (3060TI), RTX 3080 LHR, GTX 16...
# 1                        RTX 3080TI EVGA FTW3 3080 TI
# 2            RTX 3080TI GIGABYTE AORUS XTREME 3080 TI
# 3   Zotac Gaming GeForce RTX 3080Ti / RTX 3080 Ti ...
# 4             EVGA Nvidia Geforce RTX 3080Ti 12GB XC3
# 5                        MSI RTX 3080Ti Suprim X 12GB
# 6   Gigabyte Aorus GeForce RTX 3080Ti /3080 Ti Mas...
# 7      Asus ROG strix Geforce RTX 3080 Ti/3080Ti O12G
# 8   Buy in All Laptop,MacBooks  New used or spoilt...
# 9             RTX 3080TI ZOTAC AMP HOLO BLACK 3080 TI
# 10               RTX 3080TI MSI GAMING X TRIO 3080 TI
# 11                  [in stock] Galax rtx 3080ti white
# 12  (SOLD OUT) [Bundle] EVGA GeForce RTX 3080Ti/ R...
# 13                                High spec Gaming PC
# 14  PALIT RTX 3080 TI GAMINGPRO GRAPHIC CARD NVIDI...
# 15  GALAX RTX 3080 TI SG GRAPHIC CARD NVIDIA GEFOR...
# 16                          EVGA RTX 3080Ti FTW3 12GB
# 17  (Instock) Galax RTX 3080 Ti SG (1-click OC) 12...
# 18  Custom PC building, Gaming Desktops Ryzen Inte...
# 19                    RTX 3080TI MSI SUPRIM X 3080 TI
# 20        RTX 3080TI ZOTAC TRINITY OC 12G RTX 3080 TI
# 21  🔥 RTX 3080TI EVGA FTW3 NVIDIA GeForce Graphic ...
# 22  🔥 RTX 3080TI Zotac AMP HOLOBLACK NVIDIA GeForc...
# 23  Buy in All Laptop,MacBooks  New used or spoilt...
# 24  GALAX GeForce RTX™ 3080 Ti SG (1-Click OC) 12G...
# 25             LOCAL Galax RTX 3080Ti 12GB 1-Click OC
# 26               Galax SG RTX 3080TI (Local warranty)
# 27                    [Open Box] ASUS TUF OC RTX 3080
# 28                                High spec Gaming PC
# 29                      Gigabyte RTX 3080Ti Gaming OC
# 30            [1 ONLY] BNIB MSI Ventus 3X OC RTX 3090
# 31  Rtx 3080ti Full Set Gaming System (i7 6700K, 1...
# 32                        RTX 3080TI Founders Edition
# 33  🔥 RTX 3080TI OC ASUS TUF GAMING NVIDIA GeForce...
# 34                     RTX 3080Ti TUF for Strix model
# 35  Custom PC building, Gaming Desktops Ryzen Inte...
# 36                   Wtt non-lhr msi rtx 3070 to 3080
# 37  EVGA 1000W Gold Modular Supernova G+ Premium P...
# 38  DIY PC Full System AMD 5600x / 5900x / 5950X C...
# 39  [5950X + 3080TI] CUSTOM BUDGET GAMING PC SYSTE...
# 40     Quest 2 Rental VR Gaming 64GB 256GB Oculus 1 2
# 41  RTX3080ti /rtx 3080ti/ZOTAC RTX 3080 Ti TRINIT...
# 42                          Zotac rtx 3080ti amp holo
# 43                      iGame RTX3080Ti Vulcan OC 12G
# 44  RTX 3070, 3070 TI, 3080, 3080Ti BNIB Graphic C...
# 45                                Galax Rtx 3080Ti SG
# 46         BNIB Geforce RTX 3080Ti 12GB Graphics Card
# 47  Buy in All Laptop,MacBooks  New used or spoilt...
# 48  Gigabyte RTX 3070ti vision OC 8G / rtx3080ti o...
# 49                        Palit Gaming Pro RTX 3080TI
# 50  MSI RTX 3080TI GAMING X TRIO 12GB GDDR6X Graph...
# 51                   WTT PALIT RTX 3080 TI gaming pro
# 52                                High spec Gaming PC
# 53  Pcie 16x ribbon cable High Speed PC Graphics C...
# 54                  [Last] Palit RTX 3080 Ti GameRock
# 55  [ RTX 3080ti ] Gaming PC - X570, 3700X, 32gb R...
#
#                                              item_url    time_posted  \
# 0   https://sg.carousell.com/p/rtx-3060-ti-lhr-306...   12 hours ago
# 1   https://sg.carousell.com/p/rtx-3080ti-evga-ftw...     2 days ago
# 2   https://sg.carousell.com/p/rtx-3080ti-gigabyte...     2 days ago
# 3   https://sg.carousell.com/p/zotac-gaming-geforc...    14 days ago
# 4   https://sg.carousell.com/p/evga-nvidia-geforce...    23 days ago
# 5   https://sg.carousell.com/p/msi-rtx-3080ti-supr...      1 day ago
# 6   https://sg.carousell.com/p/gigabyte-aorus-gefo...    16 days ago
# 7   https://sg.carousell.com/p/asus-rog-strix-gefo...   2 months ago
# 8   https://sg.carousell.com/p/buy-in-all-laptop-m...  10 months ago
# 9   https://sg.carousell.com/p/rtx-3080ti-zotac-am...     2 days ago
# 49  https://sg.carousell.com/p/palit-gaming-pro-rt...    1 month ago
# 50  https://sg.carousell.com/p/msi-rtx-3080ti-gami...    29 days ago
# 51  https://sg.carousell.com/p/wtt-palit-rtx-3080-...    1 month ago
# 52  https://sg.carousell.com/p/high-spec-gaming-pc...     1 year ago
# 53  https://sg.carousell.com/p/pcie-16x-ribbon-cab...   2 months ago
# 54  https://sg.carousell.com/p/last-palit-rtx-3080...     8 days ago
# 55  https://sg.carousell.com/p/rtx-3080ti-gaming-p...   7 months ago
#
#     condition price
# 0   Brand new  1100
# 1   Brand new  2655
# 2   Brand new  2750
# 3   Brand new  2859
# 4         New  2499
# 5         New  3235
# 6   Brand new  2749
# 7   Brand new  2999
# 8   Well used  4100
# 9   Brand new  2550
# 10  Brand new  3028
# 11  Brand new  3000
# 12  Brand new  2899
# 13       Used   780
# 14  Brand new  2198
# 15  Brand new  2398
# 16        New  2660
# 17  Brand new  2499
# 18  Brand new   348
# 19  Brand new  3248
# 20  Brand new  2388
# 21  Brand new  2699
# 22  Brand new  2999
# 23  Well used  4100
# 24  Brand new  2399
# 25        New  3399
# 26  Brand new  2799
# 27  Brand new  2500
# 28       Used   780
# 29  Brand new  2899
# 30  Brand new  2950
# 31       狀況良好  3200
# 32  Brand new  2800
# 33  Brand new  2999
# 34       Used   299
# 35  Brand new   348
# 36   Like new     0
# 37  Brand new   259
# 38        New  5000
# 39  Brand new  7710
# 40  Brand new    12
# 41  Brand new  2388
# 42  Brand new  2600
# 43  Brand new  2459
# 44  Brand new  1499
# 45  Brand new  2400
# 46  Brand new  3200
# 47  Well used  4100
# 48  Brand new  2099
# 49  Brand new  2799
# 50  Brand new  3148
# 51   Like new  2288
# 52       Used   780
# 53  Brand new    25
# 54  Brand new  2199
# 55       幾乎全新  4999
# Results saved to rtx 3080ti.csv
# '\nTwo parse modes only differs in item divs 2nd a\nStructure of Carousell HTML FORMAT 1 (parse_mode 1):\nbody > find main > 1st div > 1st div > divs of items\n    in divs of items > parents of each item\n        parent > 1st div > 1st a is seller, 2nd a is item page\n            in 1st a: 2nd div > p is seller name, > div > p is time posted\n            in 2nd a: 2nd div > p is item name but with ... if too long, directly under 2nd a first p is price, 2nd p is condition\n        parent > 2nd div > button > span is number of likes\ntotal 24 or 25 results loaded once.\n\nStructure of Carousell HTML FORMAT 2 (parse_mode 2):\nbody > find main > 1st div > 1st div > divs of items\n    in divs of items > parents of each item\n        parent > 1st div > 1st a is seller, 2nd a is item page\n            in 1st a: 2nd div > p is seller name, > div > p is time posted\n            in 2nd a: 1st p is FULl NAME, 2nd p is price, 3rd p is description, 4th p is condition\n        parent > 2nd div > button > span is number of likes\ntotal 24 or 25 results loaded once.\n\nbody > find main > div > button to view more\nview more button loads on top of existing, so can prob spam view more then gather all items at once\nMAY NOT BE FIRST DIV! Temp workaround is to get class name of the correct item divs\n'
